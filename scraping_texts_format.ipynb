# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.lachambre.be/doc/PCRI/html/55/ip257x.html'  # Replace with the actual URL of your text file

try:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        for tag in soup.find_all("span",attrs={'lang="FR"'}):
            # contents += tag
            print(tag)
        #contents = soup.get_text()  # Extract text content from the HTML
    else:
        print("Failed to fetch the file")
except requests.exceptions.RequestException:
    print("Error fetching the file")

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.lachambre.be/doc/PCRI/html/55/ip257x.html'  # Replace with the actual URL of your text file

try:
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        span_elements = soup.find_all('span', lang='FR')  # Find all <span> elements with lang="FR"

        for span in span_elements:
            if span.find_parent('table') is None and span.find_parent('p', attrs={"NormalFR"}):  # Check if the span is not within a table
                print(span.get_text())

    else:
        print("Failed to fetch the file")
except requests.exceptions.RequestException:
    print("Error fetching the file")
# Out:
# La séance est ouverte à 14 h 33 et
# présidée par Mme Eliane Tillieux, présidente.
# La présidente:
# La séance est ouverte.
# Une série de communications et de décisions
# doivent être portées à la connaissance de la Chambre. Elles seront reprises sur
# le site web de la Chambre et insérées dans le compte rendu intégral de cette
# séance ou son annexe.
# Ministre du gouvernement fédéral présent lors
# de l'ouverture de la séance:
# Lordre du jour appelle le scrutin secret sur
# la naturalisation.
# Je vous propose de procéder au vote secret en
# salle 3, où seront distribués les bulletins de vote, à partir de
# maintenant jusque 16 h 00.
# Les membres sont priés de déposer la
# proposition de loi de naturalisation dans lurne.
# La proposition de loi de naturalisation ne peut
# pas être signée.
# Le membre qui nentend pas accorder la
# naturalisation à un demandeur biffera le nom de lintéressé sur la liste qui
# lui a été remise.
# Dès que le scrutin secret est clos, je vous
# ...
